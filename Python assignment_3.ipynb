# %% [markdown]
# ![White and Green Simple  Professional Business Project Presentation (1).jpg](attachment:5853e971-fb90-4822-814a-d7682cc45231.jpg)

# %% [markdown]
# @.1 Write a code to reverse a string.

# %%
#Ans.

string = "My name is kapil kumar"
reversed_string = string[::-1]
print(reversed_string)
# Out:
# ramuk lipak si eman yM

# %% [markdown]
# ---------------------
# @.2 Write a code to count the number of vowels in a string.

# %%
#Ans

string = "I love you so much my sweatheart"

def count_vowels(string):
    vowels = "aeiouAEIOU"
    count = 0
    for char in string:
        if char in vowels:
            count += 1
    return count

number_of_vowels = count_vowels(string)
print("Number of vowels:", number_of_vowels)
# Out:
# Number of vowels: 11

# %% [markdown]
# ---------------------
# @.3 Write a code to check if a given string is a palindrome or not.

# %%
#Ans

string = "racecar"

def is_palindrome(string):
    return string == string[::-1]

if is_palindrome(string):
    print(string, "is a palindrome")
else:
    print(string, "is not a palindrome")
# Out:
# racecar is a palindrome

# %% [markdown]
# ------------------
# @.4 Write a code to check if two given strings are anagrams of each other.

# %%
#Ans.

word1 = "kapil kumar"
word2 = "kumar kapil"


def is_anagram(word1, word2):
    str1 = sorted(word1.lower())
    str2 = sorted(word2.lower())
    return str1 == str2
if is_anagram(word1, word2):
    print(word1, "and", word2, "are anagrams")
else:
    print(word1, "and", word2, "are not anagrams")
# Out:
# kapil kumar and kumar kapil are anagrams

# %% [markdown]
# -----------------
# @.5 Write a code to find all occurrences of a given substring within another string.

# %%
#Ans

main_string = "Pwskills courses are very nice for all the types of students"
substring = "the"

def find_substring_occurrences(string, substring):
    indices = []
    index = 0
    while index < len(string):
        index = string.find(substring, index)
        if index == -1:
            break
        indices.append(index)
        index += 1
    return indices
occurrences = find_substring_occurrences(main_string.lower(), substring.lower())
if occurrences:
    print("Substring found at main_string:", occurrences)
else:
    print("Substring not found")
# Out:
# Substring found at main_string: [39]

# %% [markdown]
# -------------------
# @.6 Write a code to perform basic string compression using the counts of repeated characters.

# %%
#Ans

input_string = "kkkkkaaaapppiil"

def compress_string(s):
    if not s:
        return ""
    
    result = []
    count = 1
    
    for i in range(1, len(s)):
        if s[i] == s[i - 1]:
            count += 1
        else:
            result.append(s[i - 1] + str(count))
            count = 1
    
    result.append(s[-1] + str(count))
    return ''.join(result)


compressed_string = compress_string(input_string)
print(compressed_string)
# Out:
# k5a4p3i2l1

# %% [markdown]
# -----------------
# @.7 Write a code to determine if a string has all unique characters.

# %%
#Ans

def has_unique_characters(s):
    return len(s) == len(set(s))
    
print(has_unique_characters("abcdef"))
print(has_unique_characters("aabbcc"))
# Out:
# True
# False

# %% [markdown]
# ---------------
# @.8 Write a code to convert a given string to uppercase or lowercase.

# %%
#Ans

def convert_case(string, case):
    if case == "upper":
        return string.upper()
    elif case == "lower":
        return string.lower()
    else:
        return "Invalid case"
        
upper_case_string = convert_case(string, "upper")
lower_case_string = convert_case(string, "lower")

string = input("Write here your name: ")

print("Uppercase:", upper_case_string)
print("Lowercase:", lower_case_string)
# Out:
# Write here your name:  kapil
# Uppercase: KAPIL
# Lowercase: kapil

# %% [markdown]
# ----------------
# @.9 Write a code to count the number of words in a string.

# %%
#Ans

def count_words(string):
    words = string.split()
    return len(words)

string = input("Write here some words about yourself.")
word_count = count_words(string)
print("Number of words:", word_count)
# Out:
# Write here some words about yourself. i am kapil kumar from delhi
# Number of words: 6

# %% [markdown]
# ----------------------
# @.10 Write a code to concatenate two strings without using the + operator.

# %%
#Ans
str1 = "Kapil "
str2 = "Kumar"

def concatenate_strings(str1, str2):
    result = ""
    for char in str1:
        result += char
    for char in str2:
        result += char
    return result
concatenated_string = concatenate_strings(str1, str2)
print(concatenated_string)
# Out:
# Kapil Kumar

# %% [markdown]
# ------------------
# @.11 Write a code to remove all occurrences of a specific element from a list.

# %%
#Ans

my_list = [1, 2, 3, 2, 4, 2, 5,66,84,57,5,4,2,99]
element_to_remove = 2

def remove_element(lst, element):
    new_list = []
    for item in lst:
        if item != element:
            new_list.append(item)
    return new_list

new_list = remove_element(my_list, element_to_remove)
print(new_list)
# Out:
# [1, 3, 4, 5, 66, 84, 57, 5, 4, 99]

# %% [markdown]
# ---------------------
# @.12 Implement a code to find the second largest number in a given list of integers.

# %%
#Ans.

nums = [1, 2, 3, 2, 4, 2, 5,66,84,57,5,4,2,99]

def second_largest(nums):
    if len(nums) < 2:
        return None
    largest = second = float('-inf')
    
    for num in nums:
        if num > largest:
            second = largest
            largest = num
        elif num > second and num != largest:
            second = num
    return second if second != float('-inf') else None
print(second_largest(nums))
# Out:
# 84

# %% [markdown]
# -----------------
# @.13 Create a code to count the occurrences of each element in a list and return a dictionary with elements as keys and their counts as values.

# %%
#Ans.

def count_occurrences(lst):
    count_dict = {}
    for item in lst:
        if item in count_dict:
            count_dict[item] += 1
        else:
            count_dict[item] = 1
    return count_dict

my_list = [1, 2, 2, 3, 3, 3, 4, 5, 5, 5, 5]

result = count_occurrences(my_list)

print(result)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 1, 5: 4}

# %% [markdown]
# -------------------
# @.14 Write a code to reverse a list in-place without using any built-in reverse functions.

# %%
#Ans

def reverse_list(lst):
    left, right = 0, len(lst) - 1
    while left < right:
        lst[left], lst[right] = lst[right], lst[left]
        left += 1
        right -= 1

my_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

reverse_list(my_list)

print(my_list)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ------------------
# @.15 Implement a code to find and remove duplicates from a list while preserving the original order of elements.

# %%
#Ans

def remove_duplicates(lst):
    seen = set()  
    result = []   
    for item in lst:
        if item not in seen:
            result.append(item)  
            seen.add(item)        
    return result

my_list = [1, 2, 2, 3, 4, 4, 5, 1]

cleaned_list = remove_duplicates(my_list)

print(cleaned_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# -------------------
# @.16 Create a code to check if a given list is sorted (either in ascending or descending order) or not.

# %%
#Ans.

def is_sorted(lst):
    if len(lst) <= 1:
        return True
    ascending = all(lst[i] <= lst[i + 1] for i in range(len(lst) - 1))
    
    descending = all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1))
    
    return ascending or descending      
  
my_list = [1, 2, 3, 4, 5]
print(is_sorted(my_list))

my_list = [5, 4, 3, 2, 1]
print(is_sorted(my_list))

my_list = [1, 3, 2, 4, 5]
print(is_sorted(my_list))
# Out:
# True
# True
# False

# %% [markdown]
# -------------
# @.17 Write a code to merge two sorted lists into a single sorted list.

# %%
#Ans

def merge_sorted_lists(list1, list2):
    merged_list = []
    i, j = 0, 0

    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1

    while i < len(list1):
        merged_list.append(list1[i])
        i += 1

    while j < len(list2):
        merged_list.append(list2[j])
        j += 1
    
    return merged_list

list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]

merged_list = merge_sorted_lists(list1, list2)

print(merged_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ----------------------
# @.18 Implement a code to find the intersection of two given lists.

# %%
#Ans

def intersection_of_lists(list1, list2):

    set1 = set(list1)
    set2 = set(list2)   
    intersection = set1 & set2  
    return list(intersection)   

list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

result = intersection_of_lists(list1, list2)

print(result)
# Out:
# [3, 4, 5]

# %% [markdown]
# -------------------
# @.19 Create a code to find the union of two lists without duplicates

# %%
#Ans

list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]
result = union_of_lists(list1, list2)

def union_of_lists(list1, list2):
    set1 = set(list1)
    set2 = set(list2)
    union = set1 | set2
    return list(union)
print(result)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ---------------
# @.20 Write a code to shuffle a given list randomly without using any built-in shuffle functions.

# %%
#Ans

import random

def shuffle_list(lst):
    n = len(lst)
    for i in range(n):
        j = random.randint(i, n - 1)  
        lst[i], lst[j] = lst[j], lst[i] 

my_list = [1, 2, 3, 4, 5]

shuffle_list(my_list)

print(my_list)
# Out:
# [1, 4, 5, 2, 3]

# %% [markdown]
# ---------------
# @.21 Write a code that takes two tuples as input and returns a new tuple containing elements that are common to both input tuples.

# %%
#Ans

tuple1 = (1, 2, 3, 4, 5)
tuple2 = (3, 4, 5, 6, 7)
result = common_elements(tuple1, tuple2)

def common_elements(tuple1, tuple2):
    set1 = set(tuple1)
    set2 = set(tuple2)
    common = set1 & set2
    return tuple(common)
print(result)
# Out:
# (3, 4, 5)

# %% [markdown]
# -------------------
# @.22 Create a code that prompts the user to enter two sets of integers separated by commas. Then, print the intersection of these two sets.

# %%
#Ans

def main():
    set1 = set(map(int, input("Enter the first set of integers (separated by commas): ").split(',')))
    set2 = set(map(int, input("Enter the second set of integers (separated by commas): ").split(',')))

    intersection = set1 & set2
    print("The intersection of the two sets is:", intersection)
main()
# Out:
# Enter the first set of integers (separated by commas):  1,2,3,4,5,6
# Enter the second set of integers (separated by commas):  3,4,5,6,7,8
# The intersection of the two sets is: {3, 4, 5, 6}

# %% [markdown]
# ----------------
# @.23 Write a code to concatenate two tuples. The function should take two tuples as input and return a new tuple containing elements from both input tuples.

# %%
#Ans

def concatenate_tuples(tuple1, tuple2):
    return tuple1 + tuple2    

tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

result = concatenate_tuples(tuple1, tuple2)

print(result)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# --------------
# @.24 Develop a code that prompts the user to input two sets of strings. Then, print the elements that are present in the first set but not in the second set.

# %%
#Ans
def main():
    set1 = set(input("Enter the first set of strings (separated by commas): ").split(','))
    set2 = set(input("Enter the second set of strings (separated by commas): ").split(','))
    difference = set1 - set2
    print("Elements in the first set but not in the second set:", difference)
main()
# Out:
# Enter the first set of strings (separated by commas):  1,2,3,4,5
# Enter the second set of strings (separated by commas):  2,4,8,9,6
# Elements in the first set but not in the second set: {'3', '1', '5'}

# %% [markdown]
# -------------
# @25. Create a code that takes a tuple and two integers as input. The function should return a new tuple containing elements from the original tuple within the specified range of indices.

# %%
#Ans

def slice_tuple(original_tuple, start_index, end_index):
    return original_tuple[start_index:end_index]    

original_tuple = (10, 20, 30, 40, 50, 60)

start_index = int(input("Enter the start index: "))
end_index = int(input("Enter the end index: "))

result = slice_tuple(original_tuple, start_index, end_index)
print("The sliced tuple is:", result)
# Out:
# Enter the start index:  1
# Enter the end index:  3
# The sliced tuple is: (20, 30)

# %% [markdown]
# ----------------
# @.26 Write a code that prompts the user to input two sets of characters. Then, print the union of these two sets.

# %%
#Ans

def main():
    set1 = set(input("Enter the first set of characters (separated by commas): ").split(','))
    set2 = set(input("Enter the second set of characters (separated by commas): ").split(','))    
    union = set1 | set2 
    print("The union of the two sets is:", union)
main()
# Out:
# Enter the first set of characters (separated by commas):  1,2,3,4,5,6,7,8,9
# Enter the second set of characters (separated by commas):  2,5,8,4,9
# The union of the two sets is: {'7', '3', '1', '9', '6', '8', '4', '2', '5'}

# %% [markdown]
# --------------
# @.27 Develop a code that takes a tuple of integers as input. The function should return the maximum and minimum values from the tuple using tuple unpacking.

# %%
#Ans

input_tuple = tuple(map(int, input("Enter a tuple of integers (separated by commas): ").split(',')))

def find_max_min(int_tuple):
    max_value, min_value = max(int_tuple), min(int_tuple)
    return max_value, min_value    

max_value, min_value = find_max_min(input_tuple)

print(f"The maximum value is: {max_value}")
print(f"The minimum value is: {min_value}")
# Out:
# Enter a tuple of integers (separated by commas):  1,2,3,4,5
# The maximum value is: 5
# The minimum value is: 1

# %% [markdown]
# -------------
# @.28 Create a code that defines two sets of integers. Then, print the union, intersection, and difference of these two sets.

# %%
#Ans

set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}
union = set1 | set2
intersection = set1 & set2
difference = set1 - set2

def main():
    print("Union of the sets:", union)
    print("Intersection of the sets:", intersection)
    print("Difference of set1 and set2:", difference)
main()
# Out:
# Union of the sets: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection of the sets: {4, 5}
# Difference of set1 and set2: {1, 2, 3}

# %% [markdown]
# -------------
# @.29 Write a code that takes a tuple and an element as input. The function should return the count of occurrences of the given element in the tuple.

# %%
#Ans

def count_occurrences(input_tuple, element):
    return input_tuple.count(element)

input_tuple = tuple(map(int, input("Enter a tuple of integers (separated by commas): ").split(',')))

element = int(input("Enter the element to count: "))

count = count_occurrences(input_tuple, element)

print(f"The element {element} occurs {count} times in the tuple.")
# Out:
# Enter a tuple of integers (separated by commas):  1,1,1,2,2,2,2,2,4,4,4,4,4,8,8,8,8,86,6,6,6,3,3,3
# Enter the element to count:  8
# The element 8 occurs 4 times in the tuple.

# %% [markdown]
# -------------------
# @.30 Develop a code that prompts the user to input two sets of strings. Then, print the symmetric difference of these two sets.

# %%
#Ans

set1 = set(input("Enter the first set of strings (separated by commas): ").split(','))
set2 = set(input("Enter the second set of strings (separated by commas): ").split(','))

symmetric_difference = set1 ^ set2

def main():
    print("The symmetric difference of the two sets is:", symmetric_difference)
main()
# Out:
# Enter the first set of strings (separated by commas):  i love my country
# Enter the second set of strings (separated by commas):  are you love your country
# The symmetric difference of the two sets is: {'i love my country', 'are you love your country'}

# %% [markdown]
# -------------
# @.31 Write a code that takes a list of words as input and returns a dictionary where the keys are unique words and the values are the frequencies of those words in the input list.

# %%
#Ans.

def word_frequencies(word_list):
    frequency_dict = {}
    for word in word_list:
        if word in frequency_dict:
            frequency_dict[word] += 1
        else:
            frequency_dict[word] = 1
    return frequency_dict

input_words = input("Enter a list of words (separated by spaces): ").split()

frequencies = word_frequencies(input_words)

print("Word frequencies:", frequencies)
# Out:
# Enter a list of words (separated by spaces):  kapil, kumar, boy, love, girl, kapil, kapil, kumar, boy
# Word frequencies: {'kapil,': 3, 'kumar,': 2, 'boy,': 1, 'love,': 1, 'girl,': 1, 'boy': 1}

# %% [markdown]
# ------------------
# @.32 Write a code that takes two dictionaries as input and merges them into a single dictionary. If there are common keys, the values should be added together.

# %%
#Ans

import ast

def merge_dicts(dict1, dict2):
    merged_dict = dict1.copy()
    for key, value in dict2.items():
        if key in merged_dict:
            merged_dict[key] += value 
        else:
            merged_dict[key] = value  
    return merged_dict    

dict1 = ast.literal_eval(input("Enter the first dictionary (e.g., {'a': 1, 'b': 2}): "))

dict2 = ast.literal_eval(input("Enter the second dictionary (e.g., {'b': 3, 'c': 4}): "))

result = merge_dicts(dict1, dict2)

print("Merged dictionary:", result)
# Out:
# Enter the first dictionary (e.g., {'a': 1, 'b': 2}):  {'a': 4, 'b': 3, 'c' : 7}
# Enter the second dictionary (e.g., {'b': 3, 'c': 4}):  {'a': 4, 'b': 5, 'c' : 7}
# Merged dictionary: {'a': 8, 'b': 8, 'c': 14}

# %% [markdown]
# ---------------
# @33. Write a code to access a value in a nested dictionary. The function should take the dictionary and a list of keys as input, and return the corresponding value. If any of the keys do not exist in the dictionary, the function should return None.

# %%
#Ans

def access_nested_value(nested_dict, keys):
    current_dict = nested_dict  
    for key in keys:    
        if key in current_dict:
            current_dict = current_dict[key]  
        else:        
            return None  
    return current_dict

nested_dict = {'a': {'b': {'c': 10}}}
keys = ['a', 'b', 'c']

result = access_nested_value(nested_dict, keys)

print("The value is:", result)
# Out:
# The value is: 10

# %% [markdown]
# ---------------
# @.34 Write a code that takes a dictionary as input and returns a sorted version of it based on the values. You can choose whether to sort in ascending or descending order.

# %%
#Ans.

my_dict = eval(input("Enter the first dictionary (e.g., {'a': 1, 'b': 2}): "))


def sort_dict_by_value(d, reverse=False):
    sorted_items = sorted(d.items(), key=lambda item: item[1], reverse=reverse)
    return dict(sorted_items)

# Sort in ascending order (default)
sorted_dict_asc = sort_dict_by_value(my_dict)
print("sorted_dict_asc =", sorted_dict_asc)

# Sort in descending order
sorted_dict_desc = sort_dict_by_value(my_dict, reverse=True)
print("sorted_dict_desc =", sorted_dict_desc)
# Out:
# Enter the first dictionary (e.g., {'a': 1, 'b': 2}):  {'a': 5, 'b': 2, 'c' : 4}
# sorted_dict_asc = {'b': 2, 'c': 4, 'a': 5}
# sorted_dict_desc = {'a': 5, 'c': 4, 'b': 2}

# %% [markdown]
# -------------------
# @.35 Write a code that inverts a dictionary, swapping keys and values. Ensure that the inverted dictionary correctly handles cases where multiple keys have the same value by storing the keys as a list in the inverted dictionary.

# %%
#Ans

def invert_dict(original_dict):
    inverted_dict = {}
    for key, value in original_dict.items():

        if value in inverted_dict:
            inverted_dict[value].append(key)
        else:
            inverted_dict[value] = [key]
    return inverted_dict

original_dict = {'a': 2, 'b': 2, 'c': 1, 'd': 3, 'e': 1}

inverted = invert_dict(original_dict)

print(inverted)
# Out:
# {2: ['a', 'b'], 1: ['c', 'e'], 3: ['d']}

# %% [markdown]
#                   ---------------------------------------THANK YOU---------------------------------
#
#                                                                                                      Made by kapil kumar
